# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
df=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv', sep='\t')

# %%
df.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo=df

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
chipo.shape
# Out:
# (4622, 5)

# %%
# Solution 2

chipo.count()
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64

# %%
chipo.value_counts('item_name')
# Out:
# item_name
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
# chipo.value_counts()

# %%
chipo.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   str
#  3   choice_description  3376 non-null   str
#  4   item_price          4622 non-null   str
# dtypes: int64(2), str(3)
# memory usage: 180.7 KB

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
list(chipo.columns)
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
chipo.set_index('order_id', inplace=True)

# %%
chipo.index
# Out:
# Index([   1,    1,    1,    1,    2,    3,    3,    4,    4,    5,
#        ...
#        1831, 1831, 1831, 1832, 1832, 1833, 1833, 1834, 1834, 1834],
#       dtype='int64', name='order_id', length=4622)

# %%
chipo.head(3)
# Out:
#           quantity                     item_name choice_description item_price
# order_id
# 1                1  Chips and Fresh Tomato Salsa                NaN     $2.39
# 1                1                          Izze       [Clementine]     $3.39
# 1                1              Nantucket Nectar            [Apple]     $3.39

# %%
chipo.reset_index(inplace=True)

# %%
chipo.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
df['item_name'].value_counts().head(1)
# Out:
# item_name
# Chicken Bowl    726
# Name: count, dtype: int64

# %%
gr=df.groupby('item_name')['quantity'].sum()
gr=pd.DataFrame(gr)
gr.sort_values('quantity', ascending=False).head(1)
# Out:
#               quantity
# item_name
# Chicken Bowl       761

# %%
gr.reset_index(inplace=True)

# %%
gr[gr.quantity == gr.quantity.max()]['item_name'].values[0]
# Out:
# 'Chicken Bowl'

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
gr=df.groupby('item_name')['quantity'].sum()
gr=pd.DataFrame(gr)
int(gr['quantity'].max())
# Out:
# 761

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
gr2=pd.DataFrame(df.groupby('choice_description')['quantity'].sum())
gr2.head(5)
gr2[gr2.quantity==gr2.quantity.max()]
# Out:
#                     quantity
# choice_description
# [Diet Coke]              159

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
total_items=df.quantity.sum()
int(total_items)
# Out:
# 4972

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
float_func=lambda x : float(x)

result=[ float_func(x[1:]) for x in list(df['item_price']) ]

# %%
df['item_price']=result

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  item_price2
# 0                                                NaN        2.39         2.39
# 1                                       [Clementine]        3.39         3.39
# 2                                            [Apple]        3.39         3.39
# 3                                                NaN        2.39         2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        16.98

# %%
# dollarizer = lambda x: float(x[1:-1])
# chipo.item_price = chipo.item_price.apply(dollarizer)

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
df['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo['revenue_generated']=chipo['quantity']*chipo['item_price']

# %%
total_revenue=chipo['revenue_generated'].sum()
print("$"+str(float(total_revenue)))
# Out:
# $39237.02

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
chipo.order_id.value_counts().count()
# Out:
# np.int64(1834)

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1
average_amount_per_order=(chipo['revenue_generated'].sum())/(chipo.order_id.value_counts().count())
float(average_amount_per_order)
# Out:
# 21.39423118865867

# %%
# Solution 2
chipo.groupby('order_id')['revenue'].sum().mean()
# Solution 3

chipo['revenue'] = chipo['quantity'] * chipo['item_price']
order_grouped = chipo.groupby(by=['order_id']).sum()
order_grouped.mean()['revenue']

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
float(df.item_name.value_counts().count())
# Out:
# 50.0

# %%
df.item_name.value_counts()
# Out:
# item_name
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...
